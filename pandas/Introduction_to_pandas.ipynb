# %%
import pandas as pd

# %%
# 2 main datatypes
series = pd.Series(["BMW", "TOYOTA", "HONDA"])

# %%
series
# Out:
# 0       BMW
# 1    TOYOTA
# 2     HONDA
# dtype: str

# %%
# Series = 1-dimentional

# %%
colours = pd.Series(["RED", "BLUE", "WHITE"])
colours
# Out:
# 0      RED
# 1     BLUE
# 2    WHITE
# dtype: str

# %%
# DataFrame = 2-dimentional
car_data = pd.DataFrame({"Car make": series,
                         "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    RED
# 1   TOYOTA   BLUE
# 2    HONDA  WHITE

# %%
# Import Data
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Exporting a dataframe
car_sales.to_csv("exported-car-sale.csv", index= False)

# %%
exported_car_sale = pd.read_csv("exported-car-sale.csv")
exported_car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data

# %%
# Attribute/instance
car_sales.dtypes

# Function
#car_sales.to_csv()
# Out:
# Make               str
# Colour             str
# Odometer (KM)    int64
# Doors            int64
# Price              str
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='str')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     str
#  1   Colour         10 non-null     str
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes

# %%
car_sales.mean(numeric_only = True )
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([3000, 1500, 111250])
car_prices.mean()
# Out:
# np.float64(38583.333333333336)

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(['dog', 'cat', 'bird', 'panda', 'snake'], index= [0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      dog
# 3      cat
# 9     bird
# 8    panda
# 3    snake
# dtype: str

# %%
animals.loc[3]
# Out:
# 3      cat
# 3    snake
# dtype: str

# %%
animals.loc[9]
# Out:
# 'bird'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      dog
# 3      cat
# 9     bird
# 8    panda
# 3    snake
# dtype: str

# %%
# .iloc refers to position original index(starts from 0) wherease .loc refers to index number(1,2,3...)
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      dog
# 3      cat
# 9     bird
# 8    panda
# 3    snake
# dtype: str

# %%
# slicing [start:End:step]
animals.iloc[:3]
# Out:
# 0     dog
# 3     cat
# 9    bird
# dtype: str

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: str

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: str

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# will not work as there is a space in column name
car_sales.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14256\240837061.py in ?()
# ----> 1 car_sales.Odometer (KM)
#
# D:\Cources_Zero_to_Mastery\Machine_learning\programs\env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
car_sales[car_sales['Make'] == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby
car_sales.groupby(['Make']).mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales.groupby(['Make', 'Colour']).mean(numeric_only=True).loc[('Toyota', 'White')]
# Out:
# Odometer (KM)    105021.5
# Doors                 4.0
# Name: (Toyota, White), dtype: float64

# %%
car_sales[(car_sales['Make'] == 'Toyota') & (car_sales['Colour'] == 'White')]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].plot(color = '#02f7e3')
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
# wouldn't work as our price is a object(String) so first covert it into integer
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 car_sales["Price"].plot()
#
# File D:\Cources_Zero_to_Mastery\Machine_learning\programs\env\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File D:\Cources_Zero_to_Mastery\Machine_learning\programs\env\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plt.draw_if_interactive()
#      73 return plot_obj.result
#
# ...

# %%
car_sales["Price"] = car_sales["Price"].str.replace('$', '').str.replace(',', '').astype(float).astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace('$', '').str.replace(',', '').astype(float).astype(int)
#
# File D:\Cources_Zero_to_Mastery\Machine_learning\programs\env\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File D:\Cources_Zero_to_Mastery\Machine_learning\programs\env\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: str

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Make"] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].mean()
# Out:
# np.float64(92302.66666666667)

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.fillna({'Odometer':car_sales_missing['Odometer'].mean()}, inplace= True)
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv('car-sales-missing-dropped.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called Seats
car_sales['Seats'] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    NaN
# 6   honda   Blue          45698      4   7500    NaN
# 7   honda   Blue          54738      4   7000    NaN
# 8  toyota  White          60000      4   6250    NaN
# 9  nissan  White          31600      4   9700    NaN

# %%
car_sales.fillna({'Seats' : 5}, inplace=True)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  toyota  White         150043      4   4000    5.0
# 1   honda    Red          87899      4   5000    5.0
# 2  toyota   Blue          32549      3   7000    5.0
# 3     bmw  Black          11179      5  22000    5.0
# 4  nissan  White         213095      4   3500    5.0
# 5  toyota  Green          99213      4   4500    5.0
# 6   honda   Blue          45698      4   7500    5.0
# 7   honda   Blue          54738      4   7000    5.0
# 8  toyota  White          60000      4   6250    5.0
# 9  nissan  White          31600      4   9700    5.0

# %%
# Column from Python List
Fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 4.5]
car_sales['fuel per 100KM'] = Fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5

# %%
car_sales["Total fuel used(L)"] = car_sales["Odometer (KM)"]/100 * car_sales['fuel per 100KM']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used  Total fuel used(L)
# 0        11253.225           11253.225
# 1         8086.708            8086.708
# 2         1627.450            1627.450
# 3         1073.184            1073.184
# ...

# %%
car_sales.drop(labels= 'Total fuel used', axis= 1, inplace= True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used(L)
# 0           11253.225
# 1            8086.708
# 2            1627.450
# 3            1073.184
# 4           18539.265
# 5            4663.011
# 6            3473.048
# ...

# %%
# Create a column from single Value
car_sales['Number of Wheels'] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels
# 0           11253.225                 4
# 1            8086.708                 4
# 2            1627.450                 4
# 3            1073.184                 4
# ...

# %%
car_sales['Passed Road Saftey'] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# ...

# %%
car_sales['Number of Ownership Transfer'] = pd.Series([5, 2, 3, 1, 6, 2, 3, 1, 2, 1], dtype= int)

# %%
#car_sales.drop('Number of Owners', axis=1, inplace= True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey  \
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# ...

# %%
car_sales_Shuffled = car_sales.sample(frac=1)

# %%
car_sales_Shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 4  nissan  White         213095      4   3500    5.0             8.7
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 8  toyota  White          60000      4   6250    5.0             3.0
# 1   honda    Red          87899      4   5000    5.0             9.2
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey  \
# 0           11253.225                 4                True
# 2            1627.450                 4                True
# ...

# %%
# only select 20% or less of data in real case senario as manipulating millions of rows take alot of time
car_sales_Shuffled.sample(frac= 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 4  nissan  White         213095      4   3500    5.0             8.7
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey  \
# 5            4663.011                 4                True
# 4           18539.265                 4                True
#
#    Number of Ownership Transfer
# 5                             2
# 4                             6

# %%
car_sales_Shuffled.reset_index(drop= True, inplace= True)

# %%
car_sales_Shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1  toyota   Blue          32549      3   7000    5.0             5.0
# 2  nissan  White         213095      4   3500    5.0             8.7
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  toyota  White          60000      4   6250    5.0             3.0
# 5   honda    Red          87899      4   5000    5.0             9.2
# 6  toyota  Green          99213      4   4500    5.0             4.7
# 7   honda   Blue          45698      4   7500    5.0             7.6
# 8   honda   Blue          54738      4   7000    5.0             8.7
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey  \
# 0           11253.225                 4                True
# 1            1627.450                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White         150043      4   4000    5.0             7.5
# 1   honda    Red          87899      4   5000    5.0             9.2
# 2  toyota   Blue          32549      3   7000    5.0             5.0
# 3     bmw  Black          11179      5  22000    5.0             9.6
# 4  nissan  White         213095      4   3500    5.0             8.7
# 5  toyota  Green          99213      4   4500    5.0             4.7
# 6   honda   Blue          45698      4   7500    5.0             7.6
# 7   honda   Blue          54738      4   7000    5.0             8.7
# 8  toyota  White          60000      4   6250    5.0             3.0
# 9  nissan  White          31600      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey  \
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# ...

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: x / 1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White      93776.875      4   4000    5.0             7.5
# 1   honda    Red      54936.875      4   5000    5.0             9.2
# 2  toyota   Blue      20343.125      3   7000    5.0             5.0
# 3     bmw  Black       6986.875      5  22000    5.0             9.6
# 4  nissan  White     133184.375      4   3500    5.0             8.7
# 5  toyota  Green      62008.125      4   4500    5.0             4.7
# 6   honda   Blue      28561.250      4   7500    5.0             7.6
# 7   honda   Blue      34211.250      4   7000    5.0             8.7
# 8  toyota  White      37500.000      4   6250    5.0             3.0
# 9  nissan  White      19750.000      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey  \
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# ...

# %%
car_sales.rename(columns={'Odometer (KM)': 'Odometer (MILE)'}, inplace= True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (MILE)  Doors  Price  Seats  fuel per 100KM  \
# 0  toyota  White        93776.875      4   4000    5.0             7.5
# 1   honda    Red        54936.875      4   5000    5.0             9.2
# 2  toyota   Blue        20343.125      3   7000    5.0             5.0
# 3     bmw  Black         6986.875      5  22000    5.0             9.6
# 4  nissan  White       133184.375      4   3500    5.0             8.7
# 5  toyota  Green        62008.125      4   4500    5.0             4.7
# 6   honda   Blue        28561.250      4   7500    5.0             7.6
# 7   honda   Blue        34211.250      4   7000    5.0             8.7
# 8  toyota  White        37500.000      4   6250    5.0             3.0
# 9  nissan  White        19750.000      4   9700    5.0             4.5
#
#    Total fuel used(L)  Number of Wheels  Passed Road Saftey  \
# 0           11253.225                 4                True
# 1            8086.708                 4                True
# ...
